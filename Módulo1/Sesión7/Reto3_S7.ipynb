# %% [markdown]
# # Reto3: Realizando operaciones con Colecciones e importando datos

# %% [markdown]
# ### Se crearon las colecciones "users","movies" y  "ratings"

# %% [markdown]
# ![Captura%20de%20pantalla%20de%202020-11-25%2023-57-10.png](attachment:Captura%20de%20pantalla%20de%202020-11-25%2023-57-10.png)

# %% [markdown]
# ### Posteriormente, los datos fueron agregados a cada una.

# %% [markdown]
# ![Captura%20de%20pantalla%20de%202020-11-25%2023-56-52.png](attachment:Captura%20de%20pantalla%20de%202020-11-25%2023-56-52.png)

# %% [markdown]
# ![Captura%20de%20pantalla%20de%202020-11-25%2023-49-27.png](attachment:Captura%20de%20pantalla%20de%202020-11-25%2023-49-27.png)

# %% [markdown]
# ![Captura%20de%20pantalla%20de%202020-11-25%2023-49-31.png](attachment:Captura%20de%20pantalla%20de%202020-11-25%2023-49-31.png)
