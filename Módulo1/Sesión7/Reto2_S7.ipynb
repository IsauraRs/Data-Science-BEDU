# %% [markdown]
# # Reto 2: Importando datos a una tabla en formato CSV

# %% [markdown]
# ### Una vez creadas las tablas en el reto uno se han importado los archivos CSV por medio del "Table Data Import Wizard".

# %%
SELECT * 
FROM movies;

# %% [markdown]
# ![Captura%20de%20pantalla%20de%202020-11-25%2023-27-46.png](attachment:Captura%20de%20pantalla%20de%202020-11-25%2023-27-46.png)

# %%
SELECT *
FROM ratings;

# %% [markdown]
# ![Captura%20de%20pantalla%20de%202020-11-25%2023-31-54.png](attachment:Captura%20de%20pantalla%20de%202020-11-25%2023-31-54.png)
